# %%
import os
import sys
import fastmri
os.chdir('test_model')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-c33d432abbef> in <module>
#       1 import os
#       2 import sys
# ----> 3 import fastmri
#       4 os.chdir('test_model')
#
# ModuleNotFoundError: No module named 'fastmri'

# %%
sys.path.append('/home/batman/Documents/cs282a/proj/test_model/data/fastmri')
print(sys.path)
# Out:
# ['/home/batman/Documents/cs282a/proj/test_model', '/home/batman/anaconda3/lib/python38.zip', '/home/batman/anaconda3/lib/python3.8', '/home/batman/anaconda3/lib/python3.8/lib-dynload', '', '/home/batman/.local/lib/python3.8/site-packages', '/home/batman/anaconda3/lib/python3.8/site-packages', '/home/batman/anaconda3/lib/python3.8/site-packages/locket-0.2.1-py3.8.egg', '/home/batman/anaconda3/lib/python3.8/site-packages/IPython/extensions', '/home/batman/.ipython', './data/fastmri', './data/fastmri', '/home/batman/Documents/cs282a/proj/test_model/data/fastmri', '/home/batman/Documents/cs282a/proj/test_model/data/fastmri']

# %%
# combine mag and phase data for training
path_to_data = '/home/batman/Documents/cs282/proj/cs282/fastMRI'

#!python datasets/combine_A_and_B.py --fold_A /path/to/data/A --fold_B /path/to/data/B --fold_AB /path/to/data

# !python datasets/combine_A_and_B.py --fold_A /home/batman/Documents/cs282a/proj/cs282/A --fold_B /home/batman/Documents/cs282a/proj/cs282/B --fold_AB /home/batman/Documents/cs282a/proj/cs282/AB_normalize
# Out:
# [fold_A] =  /home/batman/Documents/cs282a/proj/cs282/A
# [fold_B] =  /home/batman/Documents/cs282a/proj/cs282/B
# [fold_AB] =  /home/batman/Documents/cs282a/proj/cs282/AB_normalize
# [num_imgs] =  1000000
# [use_AB] =  False
# [no_multiprocessing] =  False
# Traceback (most recent call last):
#   File "datasets/combine_A_and_B.py", line 35, in <module>
#     splits = os.listdir(args.fold_A)
# FileNotFoundError: [Errno 2] No such file or directory: '/home/batman/Documents/cs282a/proj/cs282/A'

# %%
# %%time
# train
#os.environ['MKL_THREADING_LAYER'] = 'GNU'
#../AB_dataset/train

# !python train.py --dataroot ./datasets/A --dataroot2 ./datasets/K --dataset_mode fastmri --name mag2kspace_pix2pix --model pix2pix --direction AtoB --input_nc=1 --output_nc=2 --gpu_ids=0,1 --display_id=0 --batch_size=1 --continue_train --epoch_count=73
# Out:
# ----------------- Options ---------------
#                batch_size: 1
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#            continue_train: True                          	[default: False]
#                 crop_size: 256
#                  dataroot: ./datasets/A                  	[default: None]
#                 dataroot2: ./datasets/K                  	[default: None]
#              dataset_mode: fastmri                       	[default: aligned]
#                 direction: AtoB
#               display_env: main
#              display_freq: 400
#                display_id: 0                             	[default: 1]
#             display_ncols: 4
#              display_port: 8097
#            display_server: http://localhost
#           display_winsize: 256
#                     epoch: latest
#               epoch_count: 73                            	[default: 1]
#                  gan_mode: vanilla
# ...

# %%
# !ls checkpoints
# Out:
# facades_label2photo_pretrained	mag2phase_1e5_pix2pix
# facades_pix2pix			mag2phase_AtoB_pix2pix
# fastmri_pix2pix			mag2phase_normalize_pix2pix
# mag2kspace_pix2pix		mag2phase_normal_pix2pix
# mag2phase_1e4_pix2pix		mag2phase_pix2pix

# %%
# testing

# !python test.py --dataroot ./datasets/AB_normalize --direction AtoB --model pix2pix --name mag2phase_normalize_pix2pix --input_nc=1 --output_nc=1 --num_test=200
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                 crop_size: 256
#                  dataroot: ./datasets/AB_normalize       	[default: None]
#              dataset_mode: aligned
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1                             	[default: 3]
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: pix2pix                       	[default: test]
#                n_layers_D: 3
# ...

# %%
import matplotlib.pyplot as plt

img = plt.imread('./results/mag2phase_normalize_pix2pix/test_latest/images/1147_fake_B.png')
plt.imshow(img)
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt

img = plt.imread('./results/mag2phase_normalize_pix2pix/test_latest/images/1101_real_A.png')
plt.imshow(img)#, vmin=0, vmax=0.0002)
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt

img = plt.imread('./results/mag2phase_normalize_pix2pix/test_latest/images/1147_real_B.png')
plt.imshow(img)#, vmin=0, vmax=0.01)
plt.colorbar()
plt.show()
